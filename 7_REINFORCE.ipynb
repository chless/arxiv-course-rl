# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

# %% [markdown]
# # Model

# %%
class REINFORCE(nn.Module):
    def __init__(self):
        super(REINFORCE, self).__init__()
        self.linear_1 = nn.Linear(4, 128)
        self.linear_2 = nn.Linear(128, 2)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        self.data = []
        
    def policy(self, state):
        x = F.relu(self.linear_1(state))
        prob = F.softmax(self.linear_2(x), dim=0)
        return prob
    
    def get_action(self, state):
        prob = self.policy(torch.from_numpy(state).float())
        dist = Categorical(prob)
        action = dist.sample()
        return action.item(), prob
      
    def save(self, item):
        self.data.append(item)
        
    def update(self):
        G = 0
        self.optimizer.zero_grad()
        for reward, prob in self.data[::-1]:
            G = reward + gamma * G
            loss = - torch.log(prob) * G
            loss.backward()
        self.optimizer.step()
        self.data = []

# %% [markdown]
# # Train

# %%
# Hyperparameters
learning_rate = 0.0002
gamma         = 0.98

# Run configurations
print_every = 100
num_episodes = 10000

# %%
def train(agent, env):
    G = 0.0
    for n_epi in range(num_episodes):
        state = env.reset()
        done = False
        
        while not done:
            action, prob = agent.get_action(state)
            next_state, reward, done, _ = env.step(action)
            agent.save((reward, prob[action]))
            state = next_state
            G += reward
            
        agent.update()
        
        if n_epi % print_every==0 and n_epi!=0:
            avg_return = G / print_every
            print("# of episode :{}, avg score : {}".format(n_epi, avg_return))
            G = 0.0
            if avg_return >= 200:
                break
    env.close()

# %%
cartpole = gym.make('CartPole-v0')
reinforce = REINFORCE()

train(reinforce, cartpole)
# Out:
# # of episode :20, avg score : 22.35
# # of episode :40, avg score : 21.4
# # of episode :60, avg score : 24.5
# # of episode :80, avg score : 23.5
# # of episode :100, avg score : 25.9
# # of episode :120, avg score : 23.6
# # of episode :140, avg score : 18.95
# # of episode :160, avg score : 22.75
# # of episode :180, avg score : 27.1
# # of episode :200, avg score : 24.9
# # of episode :220, avg score : 29.45
# # of episode :240, avg score : 35.05
# # of episode :260, avg score : 35.4
# # of episode :280, avg score : 33.6
# # of episode :300, avg score : 28.65
# # of episode :320, avg score : 34.1
# # of episode :340, avg score : 34.3
# # of episode :360, avg score : 46.15
# # of episode :380, avg score : 44.3
# # of episode :400, avg score : 54.85
# # of episode :420, avg score : 38.9
# # of episode :440, avg score : 40.4
# # of episode :460, avg score : 44.55
# # of episode :480, avg score : 49.75
# # of episode :500, avg score : 39.4
# # of episode :520, avg score : 44.25
# # of episode :540, avg score : 50.6
# # of episode :560, avg score : 47.95
# # of episode :580, avg score : 44.9
# # of episode :600, avg score : 54.4
# # of episode :620, avg score : 54.8
# # of episode :640, avg score : 55.45
# # of episode :660, avg score : 46.1
# # of episode :680, avg score : 57.5
# # of episode :700, avg score : 52.2
# # of episode :720, avg score : 63.95
# # of episode :740, avg score : 57.3
# # of episode :760, avg score : 62.8
# # of episode :780, avg score : 67.2
# # of episode :800, avg score : 56.2
# # of episode :820, avg score : 56.05
# # of episode :840, avg score : 63.15
# # of episode :860, avg score : 78.7
# # of episode :880, avg score : 87.55
# # of episode :900, avg score : 77.15
# # of episode :920, avg score : 85.65
# # of episode :940, avg score : 64.35
# # of episode :960, avg score : 92.55
# # of episode :980, avg score : 98.8
# # of episode :1000, avg score : 97.9
# # of episode :1020, avg score : 131.3
# # of episode :1040, avg score : 101.3
# # of episode :1060, avg score : 105.3
# # of episode :1080, avg score : 82.0
# # of episode :1100, avg score : 107.85
# # of episode :1120, avg score : 130.75
# # of episode :1140, avg score : 105.95
# # of episode :1160, avg score : 118.7
# # of episode :1180, avg score : 109.9
# # of episode :1200, avg score : 143.3
# # of episode :1220, avg score : 127.9
# # of episode :1240, avg score : 139.45
# # of episode :1260, avg score : 134.7
# # of episode :1280, avg score : 110.4
# # of episode :1300, avg score : 133.9
# # of episode :1320, avg score : 160.2
# # of episode :1340, avg score : 140.85
# # of episode :1360, avg score : 139.65
# # of episode :1380, avg score : 137.85
# # of episode :1400, avg score : 166.75
# # of episode :1420, avg score : 149.65
# # of episode :1440, avg score : 164.35
# # of episode :1460, avg score : 141.3
# # of episode :1480, avg score : 158.45
# # of episode :1500, avg score : 142.8
# # of episode :1520, avg score : 159.1
# # of episode :1540, avg score : 170.85
# # of episode :1560, avg score : 181.25
# # of episode :1580, avg score : 164.75
# # of episode :1600, avg score : 158.5
# # of episode :1620, avg score : 175.05
# # of episode :1640, avg score : 154.35
# # of episode :1660, avg score : 182.85
# # of episode :1680, avg score : 173.0
# # of episode :1700, avg score : 171.15
# # of episode :1720, avg score : 152.5
# # of episode :1740, avg score : 146.1
# # of episode :1760, avg score : 172.5
# # of episode :1780, avg score : 158.35
# # of episode :1800, avg score : 179.3
# # of episode :1820, avg score : 184.55
# # of episode :1840, avg score : 163.7
# # of episode :1860, avg score : 184.05
# # of episode :1880, avg score : 179.35
# # of episode :1900, avg score : 191.35
# # of episode :1920, avg score : 179.05
# # of episode :1940, avg score : 178.35
# # of episode :1960, avg score : 185.05
# # of episode :1980, avg score : 174.65
# # of episode :2000, avg score : 191.45
# # of episode :2020, avg score : 183.45
# # of episode :2040, avg score : 177.75
# # of episode :2060, avg score : 181.65
# # of episode :2080, avg score : 171.9
# # of episode :2100, avg score : 183.05
# # of episode :2120, avg score : 180.2
# # of episode :2140, avg score : 194.4
# # of episode :2160, avg score : 172.15
# # of episode :2180, avg score : 159.35
# # of episode :2200, avg score : 180.3
# # of episode :2220, avg score : 178.3
# # of episode :2240, avg score : 181.0
# # of episode :2260, avg score : 169.9
# # of episode :2280, avg score : 181.25
# # of episode :2300, avg score : 178.4
# # of episode :2320, avg score : 178.45
# # of episode :2340, avg score : 165.95
# # of episode :2360, avg score : 165.8
# # of episode :2380, avg score : 182.15
# # of episode :2400, avg score : 170.75
# # of episode :2420, avg score : 186.65
# # of episode :2440, avg score : 187.7
# # of episode :2460, avg score : 172.35
# # of episode :2480, avg score : 184.15
# # of episode :2500, avg score : 189.3
# # of episode :2520, avg score : 183.4
# # of episode :2540, avg score : 175.65
# # of episode :2560, avg score : 179.8
# # of episode :2580, avg score : 193.2
# # of episode :2600, avg score : 189.4
# # of episode :2620, avg score : 190.25
# # of episode :2640, avg score : 186.15
# # of episode :2660, avg score : 186.15
# # of episode :2680, avg score : 173.4
# # of episode :2700, avg score : 180.25
# # of episode :2720, avg score : 190.2
# # of episode :2740, avg score : 174.9
# # of episode :2760, avg score : 186.1
# # of episode :2780, avg score : 185.8
# # of episode :2800, avg score : 185.95
# # of episode :2820, avg score : 188.8
# # of episode :2840, avg score : 171.5
# # of episode :2860, avg score : 189.25
# # of episode :2880, avg score : 185.45
# # of episode :2900, avg score : 191.05
# # of episode :2920, avg score : 187.7
# # of episode :2940, avg score : 180.2
# # of episode :2960, avg score : 190.35
# # of episode :2980, avg score : 193.95
# # of episode :3000, avg score : 184.3
# # of episode :3020, avg score : 192.3
# # of episode :3040, avg score : 180.45
# # of episode :3060, avg score : 177.85
# # of episode :3080, avg score : 185.4
# # of episode :3100, avg score : 192.6
# # of episode :3120, avg score : 183.65
# # of episode :3140, avg score : 187.5
# # of episode :3160, avg score : 173.25
# # of episode :3180, avg score : 173.15
# # of episode :3200, avg score : 166.9
# # of episode :3220, avg score : 176.8
# # of episode :3240, avg score : 183.65
# # of episode :3260, avg score : 191.1
# # of episode :3280, avg score : 180.1
# # of episode :3300, avg score : 191.7
# # of episode :3320, avg score : 185.85
# # of episode :3340, avg score : 192.4
# # of episode :3360, avg score : 188.9
# # of episode :3380, avg score : 183.8
# # of episode :3400, avg score : 195.9
# # of episode :3420, avg score : 191.6
# # of episode :3440, avg score : 188.8
# # of episode :3460, avg score : 184.65
# # of episode :3480, avg score : 183.6
# # of episode :3500, avg score : 193.45
# # of episode :3520, avg score : 194.75
# # of episode :3540, avg score : 182.2
# # of episode :3560, avg score : 181.2
# # of episode :3580, avg score : 180.95
# # of episode :3600, avg score : 198.4
# # of episode :3620, avg score : 186.4
# # of episode :3640, avg score : 199.8
# # of episode :3660, avg score : 186.45
# # of episode :3680, avg score : 189.85
# # of episode :3700, avg score : 192.1
# # of episode :3720, avg score : 193.0
# # of episode :3740, avg score : 173.6
# # of episode :3760, avg score : 197.15
# # of episode :3780, avg score : 194.15
# # of episode :3800, avg score : 196.15
# # of episode :3820, avg score : 192.05
# # of episode :3840, avg score : 198.45
# # of episode :3860, avg score : 196.2
# # of episode :3880, avg score : 199.7
# # of episode :3900, avg score : 195.65
# # of episode :3920, avg score : 175.05
# # of episode :3940, avg score : 191.5
# # of episode :3960, avg score : 188.05
# # of episode :3980, avg score : 182.65
# # of episode :4000, avg score : 183.9
# # of episode :4020, avg score : 185.95
# # of episode :4040, avg score : 196.9
# # of episode :4060, avg score : 192.0
# # of episode :4080, avg score : 191.7
# # of episode :4100, avg score : 195.9
# # of episode :4120, avg score : 194.85
# # of episode :4140, avg score : 183.4
# # of episode :4160, avg score : 182.8
# # of episode :4180, avg score : 183.4
# # of episode :4200, avg score : 175.6
# # of episode :4220, avg score : 186.1
# # of episode :4240, avg score : 187.8
# # of episode :4260, avg score : 192.4
# # of episode :4280, avg score : 199.8
# # of episode :4300, avg score : 191.8
# # of episode :4320, avg score : 195.75
# # of episode :4340, avg score : 197.35
# # of episode :4360, avg score : 184.9
# # of episode :4380, avg score : 194.35
# # of episode :4400, avg score : 196.85
# # of episode :4420, avg score : 193.2
# # of episode :4440, avg score : 191.1
# # of episode :4460, avg score : 192.1
# # of episode :4480, avg score : 189.45
# # of episode :4500, avg score : 196.9
# # of episode :4520, avg score : 198.2
# # of episode :4540, avg score : 195.4
# # of episode :4560, avg score : 197.1
# # of episode :4580, avg score : 191.9
# # of episode :4600, avg score : 197.45
# # of episode :4620, avg score : 194.45
# # of episode :4640, avg score : 189.9
# # of episode :4660, avg score : 194.75
# # of episode :4680, avg score : 188.15
# # of episode :4700, avg score : 169.95
# # of episode :4720, avg score : 193.45
# # of episode :4740, avg score : 195.2
# # of episode :4760, avg score : 191.55
# # of episode :4780, avg score : 197.8
# # of episode :4800, avg score : 191.9
# # of episode :4820, avg score : 196.75
# # of episode :4840, avg score : 197.45
# # of episode :4860, avg score : 190.85
# # of episode :4880, avg score : 200.0
